# %%
import xarray as xr

# %%
from pathlib import Path

date = "2026-08-09"
cycle = "00z"
FULL_PATH = Path.cwd().resolve().parent / "data" / "IFS" / date /"netCDF" / cycle / f"ALL-{date}-{cycle}.nc"

# %%
ds = xr.open_dataset(FULL_PATH)

# %%
ds
# Out:
# <xarray.Dataset> Size: 9kB
# Dimensions:             (valid_time: 3, station: 4, soilLayer: 4,
#                          isobaricInhPa: 14)
# Coordinates: (12/14)
#   * valid_time          (valid_time) datetime64[ns] 24B 2026-08-10 ... 2026-0...
#     step                (valid_time) timedelta64[ns] 24B ...
#   * station             (station) <U10 160B 'Fehmarn' ... 'Norderney'
#     latitude            (station) float64 32B ...
#     longitude           (station) float64 32B ...
#   * soilLayer           (soilLayer) float64 32B 1.0 2.0 3.0 4.0
#     ...                  ...
#     surface             float64 8B ...
#     heightAboveGround   float64 8B ...
#     entireAtmosphere    float64 8B ...
#     mostUnstableParcel  float64 8B ...
#     nominalTop          float64 8B ...
#     meanSea             float64 8B ...
# Data variables: (12/43)
#     tp                  (valid_time, station) float32 48B ...
#     sp                  (valid_time, station) float32 48B ...
#     sve                 (valid_time, station) float32 48B ...
#     mx2t3               (valid_time, station) float32 48B ...
#     tcw                 (valid_time, station) float32 48B ...
#     svn                 (valid_time, station) float32 48B ...
#     ...                  ...
#     ro                  (valid_time, station) float32 48B ...
#     v                   (valid_time, station, isobaricInhPa) float32 672B ...
#     u                   (valid_time, station, isobaricInhPa) float32 672B ...
#     sd                  (valid_time, station) float32 48B ...
#     sf                  (valid_time, station) float32 48B ...
#     msl                 (valid_time, station) float32 48B ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-08-18T15:40 GRIB to CDM+CF via cfgrib-0.9.1...
